# %%
# install dependencies
! @ pip install ydata-profiling   # its necessary to restart the kernel

# %%
import pandas as pd
import datetime

# read raw_df
# df = pd.read_csv('https://raw.githubusercontent.com/srlucasromulo/PPGCC-DS-DeepLearning/main/data/sjdr_raw.csv', low_memory=False, sep=',')     # TODO subir raw
df = pd.read_csv('https://raw.githubusercontent.com/srlucasromulo/PPGCC-DS-DeepLearning/main/data/sjdr.csv', low_memory=False, sep=',')

# rectify date/hour columns
df.data = df.data.apply(lambda x: datetime.datetime.strptime(x, '%Y-%m-%d').date())
df.hora = df.hora.apply(lambda x: datetime.time(int(x/100)))

# join date/hour
df['data_hora'] = df.apply(lambda x: datetime.datetime.combine(x['data'], x['hora']), axis=1)
df.sort_values(by='data_hora', inplace=True, ignore_index=True)

# create time feature (represents time passing) from index
df['time'] = df.index

# create seasons features


# create time feature (represents the time-series)  f: (curr_date - start) * 24 + (curr_hour / 100)
# start_date = df.data.min()  # get start_date
# df['time'] = df.apply(lambda x: (x['data'] - start_date).days * 24, axis=1)
# for row in df.iloc:
# 	print(row['data'], (row['data']-start_date))
# # order by time feature
# df.sort_values(by='time', inplace=True, ignore_index=True)
#
# # save to file
# # df.to_csv('./data/sjdr.csv', sep=',', index=False)
# Out:
#           time        data      hora  chuva  pressao   radiacao  temperatura  \
# 0            0  2006-06-08  00:00:00    NaN      NaN        NaN          NaN
# 1            1  2006-06-08  01:00:00    NaN      NaN        NaN          NaN
# 2            2  2006-06-08  02:00:00    NaN      NaN        NaN          NaN
# 3            3  2006-06-08  03:00:00    NaN      NaN        NaN          NaN
# 4            4  2006-06-08  04:00:00    NaN      NaN        NaN          NaN
# ...        ...         ...       ...    ...      ...        ...          ...
# 144979  144979  2022-12-21  19:00:00    0.0    902.0  2783398.0         28.4
# 144980  144980  2022-12-21  20:00:00    0.0    902.1  1695221.0         27.8
# 144981  144981  2022-12-21  21:00:00    0.0    903.0   585316.0         22.9
# 144982  144982  2022-12-21  22:00:00    0.0    904.5    67735.0         20.6
# 144983  144983  2022-12-21  23:00:00    0.2    905.7    -3102.0         18.9
#
# ...

# %%
df = pd.read_csv('./data/sjdr.csv', low_memory=False, sep=',')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

figsize = (15, 5)
fig, ax = plt.subplots(figsize=figsize)
df.temperatura = df.temperatura.fillna(-30)
sns.lineplot(df, x='data_hora', y='temperatura')
# plt.xticks(rotation=90)
# Out:
# <AxesSubplot: xlabel='data_hora', ylabel='temperatura'>
# Error in callback <function _draw_all_if_interactive at 0x7f1b935bd870> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Projects/PPGCC/DS-DL/venv/lib/python3.10/site-packages/matplotlib/pyplot.py:119, in _draw_all_if_interactive()
#     117 def _draw_all_if_interactive():
#     118     if matplotlib.is_interactive():
# --> 119         draw_all()
#
# File ~/Projects/PPGCC/DS-DL/venv/lib/python3.10/site-packages/matplotlib/_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File ~/Projects/PPGCC/DS-DL/venv/lib/python3.10/site-packages/matplotlib/backend_bases.py:2054, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
# ...

# %%
# profile dataset
from ydata_profiling import ProfileReport
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/srlucasromulo/PPGCC-DS-DeepLearning/main/data/sjdr.csv', low_memory=False, sep=',')
df = df.drop(columns=['data', 'hora'])

# make profile
profile = ProfileReport(df, title="Projeto Mestrado", explorative=True, tsmode=True, sortby='time')

# save profile
profile.to_file("report_raw.html")

# %%
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# /home/lucasromulo/Projects/PPGCC/DS-DL/venv/lib/python3.10/site-packages/ydata_profiling/model/pandas/describe_timeseries_pandas.py:117: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   mad = pos_fft_above_med["ampl"].mad()
# /home/lucasromulo/Projects/PPGCC/DS-DL/venv/lib/python3.10/site-packages/ydata_profiling/model/pandas/describe_timeseries_pandas.py:117: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   mad = pos_fft_above_med["ampl"].mad()
# ...
